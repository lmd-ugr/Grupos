# %% [markdown]
# # Algoritmo de Todd Coxeter
#
# Sea G un grupo definido por una presentación \\( G = \langle X \mid R \rangle \\), donde \\( X \\) es el conjunto de generadores y \\( R\\) el conjunto de relatores. Sea \\(H = < h_1, h_2,...,h_r> \leq G \\), donde los generadores \\( h_i \\) son palabras en el alfabeto \\( X^{\pm 1} \\).

# %%
from Group import *
from ToddCoxeter import CosetTable, readGroup

# %% [markdown]
# \\[ G = \langle a, b \mid a^4, b^2 , bab^{-1}a  \rangle ,\\]
#
# \\[ H = \langle b \rangle .\\]

# %%
f = readGroup("Groups/A4.txt")
f
# Out:
# (['a', 'b', 'c'], ['aa', 'bb', 'ccc', 'abAB', 'caCBA', 'cbCA'], ['ab'])

# %%
C = CosetTable(f)
C.CosetEnumeration()
print(C.coset_table())
# Out:
# ┌───┬───┬───┬───┬───┬───┬───┐
# │ C │ a │ A │ b │ B │ c │ C │
# ├───┼───┼───┼───┼───┼───┼───┤
# │ 1 │ 2 │ 2 │ 2 │ 2 │ 3 │ 4 │
# ├───┼───┼───┼───┼───┼───┼───┤
# │ 2 │ 1 │ 1 │ 1 │ 1 │ 5 │ 6 │
# ├───┼───┼───┼───┼───┼───┼───┤
# │ 3 │ 3 │ 3 │ 5 │ 5 │ 4 │ 1 │
# ├───┼───┼───┼───┼───┼───┼───┤
# │ 4 │ 6 │ 6 │ 4 │ 4 │ 1 │ 3 │
# ├───┼───┼───┼───┼───┼───┼───┤
# │ 5 │ 5 │ 5 │ 3 │ 3 │ 6 │ 2 │
# ├───┼───┼───┼───┼───┼───┼───┤
# │ 6 │ 4 │ 4 │ 6 │ 6 │ 2 │ 5 │
# └───┴───┴───┴───┴───┴───┴───┘

# %%
C.schreier_graph(notes=False)

# %%
def print_gens(gens):
    for i in range(len(gens)):
        print(f"g{i} = {gens[i]}")
        
generators = C.getGenerators()
print_gens(generators)
# Out:
# g0 = (1, 2)(4, 6)
# g1 = (1, 2)(3, 5)
# g2 = (1, 3, 4)(2, 5, 6)

# %%
G = Group(elems=generators)
print(G)
# Out:
# Group with 12 elements: {(1, 6, 3)(2, 4, 5), (1, 4, 5)(2, 6, 3), (1, 2)(3, 5), (1, 3, 4)(2, 5, 6), (3, 5)(4, 6), (1, 5, 6)(2, 3, 4), (1, 3, 6)(2, 5, 4), (1, 4, 3)(2, 6, 5), (), (1, 5, 4)(2, 3, 6), (1, 2)(4, 6), (1, 6, 5)(2, 4, 3)}

# %%
G.table()
# Out:
# <head><style>
# table, th, td {border: 1px solid black;
#  border-collapse: collapse;}
#  th, td {padding: 15px;}</style></head><p/>
#  <table>
#  <tr> <td bgcolor='White'> * </td> <td bgcolor=Red>()</td> <td bgcolor=Yellow>(1, 6, 3)(2, 4, 5)</td> <td bgcolor=Lime>(1, 4, 5)(2, 6, 3)</td> <td bgcolor=Blue>(1, 3, 4)(2, 5, 6)</td> <td bgcolor=Tan>(3, 5)(4, 6)</td> <td bgcolor=YellowGreen>(1, 5, 6)(2, 3, 4)</td> <td bgcolor=Violet>(1, 3, 6)(2, 5, 4)</td> <td bgcolor=SkyBlue>(1, 2)(4, 6)</td> <td bgcolor=Tomato>(1, 4, 3)(2, 6, 5)</td> <td bgcolor=Plum>(1, 5, 4)(2, 3, 6)</td> <td bgcolor=PaleGreen>(1, 2)(3, 5)</td> <td bgcolor=Magenta>(1, 6, 5)(2, 4, 3)</td> </tr>
# ...

# %%
G.is_abelian()
# Out:
# False

# %% [markdown]
# \\[ G \cong D_6 \\]
# \\[ G \cong Q_3  \\]
# \\[ G \cong A_4  \\]

# %%
D6 = DihedralGroup(6)
Q3 = QuaternionGroupGeneralised(3)
A4 = AlternatingGroup(4)

G.is_isomorphic(D6), G.is_isomorphic(Q3), G.is_isomorphic(A4)
# Out:
# (False, False, True)
